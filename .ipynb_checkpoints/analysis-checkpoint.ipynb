# %% [markdown]
# # Titanic Dataset Analysis
# This notebook explores the Titanic dataset to understand passenger survival patterns.
# We will analyze trends by **class**, **gender**, and **age**, and visualize key patterns.

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv("C:/Users/mercy/titanic-analysis/data/train.csv")
df.head()
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       sex   age     fare  sibsp  parch
# 0    male  22.0   7.2500      1      0
# 1  female  38.0  71.2833      1      0
# 2  female  26.0   7.9250      0      0
# 3  female  35.0  53.1000      1      0
# 4    male  35.0   8.0500      0      0

# %%
print(df.columns)
# Out:
# Index(['survived', 'pclass', 'name', 'sex', 'age', 'fare', 'sibsp', 'parch'], dtype='str')

# %% [markdown]
# ## Overview of the dataset

# %%
# Basic info
print("Shape of dataset:", df.shape)
df.info()

# Summary statistics
df.describe()
# Out:
# Shape of dataset: (714, 8)
# <class 'pandas.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  714 non-null    int64
#  1   pclass    714 non-null    int64
#  2   name      714 non-null    str
#  3   sex       714 non-null    str
#  4   age       714 non-null    float64
#  5   fare      714 non-null    float64
#  6   sibsp     714 non-null    int64
#  7   parch     714 non-null    int64
# dtypes: float64(2), int64(4), str(2)
# memory usage: 44.8 KB
#          survived      pclass         age        fare       sibsp       parch
# count  714.000000  714.000000  714.000000  714.000000  714.000000  714.000000
# mean     0.406162    2.236695   29.699118   34.694514    0.512605    0.431373
# std      0.491460    0.838250   14.526497   52.918930    0.929783    0.853289
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# ...

# %% [markdown]
# ## Check missing values

# %%
df.isnull().sum()
# Out:
# survived    0
# pclass      0
# name        0
# sex         0
# age         0
# fare        0
# sibsp       0
# parch       0
# dtype: int64

# %% [markdown]
# Basic dataset overview

# %% [markdown]
# ## Survival count

# %%
survival_rate = df['survived'].mean()
print(f"Overall survival rate: {survival_rate:.2%}")
# Out:
# Overall survival rate: 40.62%

# %%
sns.countplot(x='survived', data=df)
plt.title("Survival Count")
plt.show()

# %% [markdown]
# ## Survival by gender

# %%
sns.countplot(x='survived', hue='sex', data=df)
plt.title("Survival by Gender")
plt.show()

# %% [markdown]
# ## Survival by gender

# %%
survival_by_gender = df.groupby('sex')['survived'].mean()
print(survival_by_gender)
# Out:
# sex
# female    0.754789
# male      0.205298
# Name: survived, dtype: float64

# %%
sns.barplot(x='sex', y='survived', data=df)
plt.title("Survival Rate by Gender")
plt.show()

# %% [markdown]
# ## Survival by Passenger class

# %%
survival_by_class = df.groupby('pclass')['survived'].mean()
print(survival_by_class)
# Out:
# pclass
# 1    0.655914
# 2    0.479769
# 3    0.239437
# Name: survived, dtype: float64

# %% [markdown]
# Chart

# %%
sns.barplot(x='pclass', y='survived', data=df)
plt.title("Survival Rate by Passenger Class")
plt.show()

# %% [markdown]
# ## Age Distribution

# %%
plt.hist(df['age'].dropna(), bins=30)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Number of Passengers")
plt.show()

# %% [markdown]
# ## Survival By Age

# %%
plt.figure(figsize=(8,5))
sns.histplot(data=df, x='age', hue='survived', bins=30, kde=True)
plt.title("Age Distribution by Survival")
plt.show()

# %% [markdown]
# ## Correlation Heatmap

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Feature Correlation Heatmap")
plt.show()

# %% [markdown]
# ## Create age groups

# %%
df['ageGroup'] = pd.cut(df['age'], bins=[0, 12, 18, 35, 60, 100],
                        labels=['Child', 'Teen', 'Adult', 'Middle-Aged', 'Senior'])

sns.countplot(x='survived', hue='ageGroup', data=df)
plt.title("survival by Age Group")
plt.show()

# %% [markdown]
# ## Key insights

# %% [markdown]
# 1. Overall survival rate was around 38%.
# 2. Female passengers had a significantly higher survival rate than males.
# 3. First-class passengers were more likely to survive than lower classes.
# 4. Younger passengers had slightly higher survival chances.
# 5. Passenger class and gender were the strongest predictors of survival.
